# %% [markdown]
# ###  Exploring and processing the company raise datasheet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load CSV from data folder

# %%
url = "data/funding_data.csv"

df = pd.read_csv(url)
df.head()
# Out:
#   DATE RAISE ANNOUNCED         COMPANY      AMOUNT        HQ Location  \
# 0            8/12/2021    pumpspotting  $1,150,000       Kittery, Me.
# 1            8/12/2021           BLDUP  $2,000,000      Boston, Mass.
# 2            8/12/2021  Sicona Battery  $2,700,000  Sydney, Australia
# 3            8/12/2021  Part Analytics  $3,000,000   Milwaukee, Wisc.
# 4            8/12/2021         Anthill  $3,000,000      Chicago, Ill.
#
#                        TOP INVESTORS (in this round)  \
# 0  MooDoos Investments, participation from Maine ...
# 1                                                  U
# 2  Artesian, Riverstone Ventures, participation f...
# 3                                         MK Capital
# 4  Rethink Education, participation from Origin V...
#
#                                                 LINK  \
# 0  https://www.finsmes.com/2021/08/pumpspotting-r...
# 1  https://www.finsmes.com/2021/08/bldup-raises-2...
# 2  https://www.finsmes.com/2021/08/sicona-battery...
# 3  https://www.finsmes.com/2021/08/part-analytics...
# 4  https://www.finsmes.com/2021/08/anthill-raises...
#
#                          Website    Round     Category  \
# 0  https://www.pumpspotting.com/      Seed     Femtech
# 1              http://bldup.com/  Pre-Seed  Enterprise
# 2  http://www.siconabattery.com/         A      Energy
# 3     https://partanalytics.com/         U  Industrial
# 4     https://www.anthillai.com/      Seed  Enterprise
#
#                                                NOTES Expansion Plans  \
# 0    community-driven breastfeeding support platform             NaN
# 1  system to highlight the relationship between b...             NaN
# 2                       battery materials technology             NaN
# 3  AI platform for sclaing global manufacturing c...             NaN
# 4  talent management platform designed for remote...             NaN
#
#   Founder First Name Founder Last Name Founder LinkedIn Founder Twitter  \
# 0                NaN               NaN              NaN             NaN
# 1                NaN               NaN              NaN             NaN
# 2                NaN               NaN              NaN             NaN
# 3                NaN               NaN              NaN             NaN
# 4                NaN               NaN              NaN             NaN
#
#   Founder AngelList Unnamed: 16
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN

# %% [markdown]
# #### Initial check on data - duplicated and unnamed column

# %% [markdown]
# It looks like there are some entries with missing raise amounts and company - this is due to the poor format of the data with total rows below the individual entries. I also looks like the unnamed column includes public email addresses when available.

# %%
len(df)
df = df.drop_duplicates()
len(df)
# Out:
# 28855

# %%
df.isnull().sum().sort_values(ascending=False)/len(df)
# Out:
# Unnamed: 16                      0.992341
# Expansion Plans                  0.943857
# Founder AngelList                0.900225
# Founder Twitter                  0.884665
# Founder LinkedIn                 0.665916
# Founder Last Name                0.629596
# Founder First Name               0.629111
# Website                          0.261722
# NOTES                            0.105493
# HQ Location                      0.105389
# Round                            0.104037
# TOP INVESTORS (in this round)    0.104003
# Category                         0.103864
# LINK                             0.103864
# DATE RAISE ANNOUNCED             0.069277
# AMOUNT                           0.000243
# COMPANY                          0.000069
# dtype: float64

# %%
df['Unnamed: 16'].unique() # unnamed column is founder_email
# Out:
# array([nan, 'cameron@tradegecko.com', 'alberto.dalmasso@satispay.com',
#        'duncan@xage.com', 'derekocarroll@brightpearl.com',
#        'terry.drayton@livible.com', 'lars.albright@sessionm.com',
#        'mcooper@skillshare.com', 'scott.mercer@voltacharging.com',
#        'jfeast@cogitocorp.com', 'dpreston@metromile.com',
#        'alex@parabola.io', 'natalies@viewpath.com', 'thar@ambersi.com',
#        'jake@realtimecases.com', 'omer.molad@vervoe.com',
#        'roy@bdsanalytics.com', 'nmondrow@lockstate.com',
#        'john.kohl@tunego.com', 'raoulpal@realvision.com',
#        'marc.castel@fiixsoftware.com', 'assaf@nanit.com',
#        'melbourne@bestow.life', 'diego.farias@amuse.io',
#        'mihkel@realeyesit.com', 'assaf@superpedestrian.com',
#        'atomarchio@cuebiq.com', 'dgloba@tradingview.com',
#        'manny.medina@outreach.io', 'alex.atallah@opensea.io',
#        'georgene.huang@fairygodboss.com', 'jjoraanstad@myriadmobile.com',
#        'ikkjin@molocoads.com', 'nate.phillips@nomnomnow.com',
#        'arianna.huffington@thriveglobal.com', 'cdoherty@fuze.com',
#        'vlad@robinhood.com', 'seth@rapchat.me', 'tj@protego.io',
#        'connor.young@amplemeal.com', 'kgardner@condati.com',
#        'rhenderson@jumpcrew.com', 'amrit@axiomexergy.com',
#        'asaf.rubin@madlan.pro', 'prasad.akella@drishtilabs.com',
#        'dudi@sckipio.com', 'jody.paterson@erpmaestro.com',
#        'lurquizu@redpoints.com', 'rotem.iram@at-bay.com',
#        'luka@peltarion.com', 'rammenon@avaamo.com', 'lklaus@keyedin.com',
#        'd.evans@fictiv.com', 'guy.bejerano@safebreach.com',
#        'yali.saar@tailorbrands.com', 'ishaan.malhi@trussle.com',
#        'steve.dineen@fuseuniversal.com', 'ben.vigoda@gamalon.com',
#        'robin.hein@simplesurance.com', 'kworkman@owletcare.com',
#        'rami.zeidan@lifehousebooks.com', 'felix.schneider@dreamlines.de',
#        'ajeet.singh@thoughtspot.com', 'kasper@carpelotion.com',
#        'akhil@stratifi.com', 'andrea.scotti@freedamedia.it',
#        'blake@getdivvy.com', 'paul.bartlett@cloudpay.net',
#        'ryan.hiring@bouncex.com', 'will.hayes@lucidworks.com',
#        'sujay.tyle@frontiercargroup.com', 'keyvan@soundhound.com',
#        'shan@zola.com', 'mpink@smartpmtech.com', 'rohit@sentenai.com',
#        'lynn.boggs@ufancards.com', 'amit.jasuja@trustedkey.com',
#        'jacob@cobalt.io', 'marcelo@mandae.com.br',
#        'chris.brandon@storageos.com', 'eli.fathi@mindbridge.ai',
#        'bassam@upbound.io', 'felix.heide@algolux.com',
#        'arram.sabeti@zerocater.com', 'oyvind@poqcommerce.com',
#        'chemi.katz@namogoo.com', 'cvause@softroboticsinc.com',
#        'roddy@hustle.com', 'todd.schwartz@skykick.com',
#        'jsallaway@vspatial.com', 'jeremy@minim.co',
#        'r.kuhl@leaselock.com', 'passayag@traackr.com',
#        'ben@numat-tech.com', 'ltibbets@ifttt.com',
#        'ryan.wuerch@dosh.cash', 'john.joseph@datanomix.net',
#        'jason.sprenkle@keydatadashboard.com', 'scaucci@1huddle.co',
#        'dokoudjou@mfsafrica.com', 'jack@thereimaginegroup.com',
#        'jonathan@squarefoot.com', 'michael.winnick@dscout.com',
#        'cbandes@pixelligent.com', 'mattduesterberg@ohmconnect.com',
#        'valerie.robitaille@xpertsea.com',
#        'keith.mcmillen@bebopsensors.com', 'steve.barha@instant.co',
#        'david.tal@agentology.com', 'noory.bechor@lawgeex.com',
#        'aj@wonolo.com', 'gshoosmith@bookingbug.com',
#        'jonathan.zweig@apponboard.com', 'mmartin@rapidsos.com',
#        'ben@greenbits.com', 'ashutosh@eightfold.ai',
#        'gil.sever@applitools.com', 'jmccandless@p-44.com',
#        'amit.saha@saviynt.com', 'jerome.lecat@scality.com',
#        'dcancel@drift.com', 'dgandler@fubo.tv',
#        'frank.jackman@localcratemeals.com', 'rahul.sidhu@spidrtech.com',
#        'riggs@honestbuildings.com', 'georgina@mybillie.com',
#        'janiv.ratson@axonize.com', 'calebhailey@sensuapp.org',
#        'will@kadena.io', 'sam@ownbackup.com', 'shyam@punchh.com',
#        'mgally@zaius.com', 'mnunez@onapsis.com', 'dilip.dubey@xeeva.com',
#        'daniel.yanisse@checkr.com', 'chloe.alpert@medinas.co',
#        'jesse.proudman@strixleviathan.com', 'aidan@hazeltechnologies.com',
#        'michael@foxtrotco.com', 'je@seamlessdocs.com',
#        'felix@joindrover.com', 'carly.zakin@skimmth.is',
#        'fangjin@imply.io', 'ahsan@kiddom.co',
#        'timothy.bean@fortemtech.com', 'erikh@kahoot.com',
#        'luke.norris@factioninc.com', 'bill.creelman@spindriftfresh.com',
#        'ryan.holmes@hootsuite.com', 'howie.liu@airtable.com',
#        'kunle.olukotun@sambanovasystems.com',
#        'mark@wardrobeessentialist.com', 'amy@unearthlabs.com',
#        'rick.weidinger@roboticvisiontech.com', 'manolo@yogome.com',
#        'tj.clark@turnkeyvr.com', 'timo.boldt@unilever.com',
#        'ken.lazarus@goscoutgo.com', 'scott.robertson@bambooventures.de',
#        'damian@domuso.com', 'rebecca@eatpakd.com',
#        'rohan@gamersensei.com', 'jcarlson@adwerx.com',
#        'michael.rovito@dwelo.com', 'rajeshk@microsoft.com',
#        'ritu@ridezum.com', 'rtaylor@getconvey.com', 'gabby@myollie.com',
#        'scott@hookit.com', 'daviderickson@forwardnetworks.com',
#        'downs_oliver@amplero.com', 'justin.effron@aliceapp.com',
#        'ian@nextcaller.com', 'alston@entefy.com', 'shai@scalemp.com',
#        'benjamin.cogan@hubblecontacts.com',
#        'patrick.bet.david@phpagency.com', 'ka.mollin@inriver.com',
#        'steve@sudoapp.com', 'ankit@curefit.com',
#        'peter.abbamonte@inprentus.com', 'stephen@boomfantasy.com',
#        'julia.salasky@crowdjustice.co.uk', 'jochem@trvl.com',
#        'kgopinathan@applieddatafinance.com', 'anshoo.sharma@magicpin.in',
#        'olegr@people.ai', 'abarrotti@touchbistro.com',
#        'phillip.hyun@gamevice.com', 'rhydian.lewis@ratesetter.com',
#        'girish@streamsets.com', 'kay.iversen@marketlogicsoftware.com',
#        'shahrishi@outcomehealth.com', 'paul@ledgerx.com',
#        'david@cornerjob.com', 'markus.becker@ecointense.de',
#        'eben_f@echodyne.com', 'kevin@idiomatic.io',
#        'christian@auto1-group.com', 'jonathan.simkin@goswift.ly',
#        'daniel.m@adext.com', 'sage@agolo.com',
#        'april.foster@inkedbrands.com', 'derrik.deyhimi@iconixx.com',
#        'subbu@bitfusion.io', 'matt@wavedash.com', 'markhammond@bons.ai',
#        'bharris@decibelinsight.com', 'dan@abundantrobotics.com',
#        'david.schlanger@progyny.com', 'king@nav.com',
#        'paul.vallee@basicincomecanada.org', 'paul.johnson@mppglobal.com',
#        'cewing@oneincsystems.com', 'dori.stein@fornova.com',
#        'brianfaux@himorty.com', 'steve@ultrahaptics.com',
#        'guy.goldstein@next-insurance.com', 'vmacchio@dinova.com',
#        'jamescrawford@orbitalinsight.com',
#        'tbuiocchi@servicechannel.info'], dtype=object)

# %% [markdown]
# As the column names are not clear, we rename these to identify which of these relate to the raise, company and founder specifically.

# %%
display(list(df.columns.values))
# Out:
# ['DATE RAISE ANNOUNCED',
#  'COMPANY',
#  'AMOUNT',
#  'HQ Location',
#  'TOP INVESTORS (in this round)',
#  'LINK',
#  'Website',
#  'Round ',
#  'Category',
#  'NOTES',
#  'Expansion Plans',
#  'Founder First Name',
#  'Founder Last Name',
#  'Founder LinkedIn',
#  'Founder Twitter',
#  'Founder AngelList',
#  'Unnamed: 16']

# %%
df.rename(columns = {'DATE RAISE ANNOUNCED':'raise_date',
 'COMPANY':'company_name',
 'AMOUNT':'raise_amount_mill_dollars',
 'HQ Location':'company_hq_location',
 'TOP INVESTORS (in this round)':'raise_top_investors',
 'LINK':'raise_link',
 'Website':'company_website',
 'Round ':'company_funding_round',
 'Category': 'company_category',
 'NOTES':'company_description',
 'Expansion Plans':'company_expansion_plans',
 'Founder First Name':'founder_first_name',
 'Founder Last Name':'founder_last_name',
 'Founder LinkedIn':'founder_linkedin',
 'Founder Twitter':'founder_twitter',
 'Founder AngelList':'founder_angelist',
 'Unnamed: 16':'founder_email'},inplace=True)

# %%
display(list(df.columns.values))
# Out:
# ['raise_date',
#  'company_name',
#  'raise_amount_mill_dollars',
#  'company_hq_location',
#  'raise_top_investors',
#  'raise_link',
#  'company_website',
#  'company_funding_round',
#  'company_category',
#  'company_description',
#  'company_expansion_plans',
#  'founder_first_name',
#  'founder_last_name',
#  'founder_linkedin',
#  'founder_twitter',
#  'founder_angelist',
#  'founder_email']

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# founder_email                28634
# company_expansion_plans      27235
# founder_angelist             25976
# founder_twitter              25527
# founder_linkedin             19215
# founder_last_name            18167
# founder_first_name           18153
# company_website               7552
# company_description           3044
# company_hq_location           3041
# company_funding_round         3002
# raise_top_investors           3001
# company_category              2997
# raise_link                    2997
# raise_date                    1999
# raise_amount_mill_dollars        7
# company_name                     2
# dtype: int64

# %%
"""
df.loc[df['company_funding_round'].isnull()] # filters rows where funding_round is null
"""

df = df[df['company_funding_round'].notna()] # select rows where funding_round is not empty
df = df.reset_index(drop=True) # reset index and remove old one
df.head()
df.shape
# Out:
# (25853, 17)

# %% [markdown]
# Inspecting the data, it looks like the data in the raise amount is a string, so we need to remove the $ and , characters so that the column can be converted to numeric type.
#
# The raise date also has some inconsistent values in, which will not convert to datetime objects - for the moment these are left in the data - as the data is ordered by date, it would be reasonable to use the previous entry date if the raise data is 'NaT' not a valid time.

# %%
df['company_hq_location'] = df['company_hq_location'].str.replace(',',';') # needed for csv upload to postgres
df['raise_top_investors'] = df['raise_top_investors'].str.replace(',',';') # needed for csv upload to postgres
df['company_description'] = df['company_description'].str.replace(',',';') # needed for csv upload to postgres
df['company_expansion_plans'] = df['company_expansion_plans'].str.replace(',',';') # needed for csv upload to postgres
df['founder_first_name'] = df['founder_first_name'].str.replace(',',';') # needed for csv upload to postgres
df['raise_link'] = df['raise_link'].str.replace(',',' ') # needed for csv upload to postgres
df['company_name'] = df['company_name'].str.replace(',',' ') # needed for csv upload to postgres

# %%
df['raise_amount_mill_dollars'] = df['raise_amount_mill_dollars'].map(lambda x: x.replace('$',''))
df['raise_amount_mill_dollars'] = df['raise_amount_mill_dollars'].map(lambda x: x.replace(',',''))
df.head()
# Out:
#   raise_date    company_name raise_amount_mill_dollars company_hq_location  \
# 0  8/12/2021    pumpspotting                   1150000        Kittery; Me.
# 1  8/12/2021           BLDUP                   2000000       Boston; Mass.
# 2  8/12/2021  Sicona Battery                   2700000   Sydney; Australia
# 3  8/12/2021  Part Analytics                   3000000    Milwaukee; Wisc.
# 4  8/12/2021         Anthill                   3000000       Chicago; Ill.
#
#                                  raise_top_investors  \
# 0  MooDoos Investments; participation from Maine ...
# 1                                                  U
# 2  Artesian; Riverstone Ventures; participation f...
# 3                                         MK Capital
# 4  Rethink Education; participation from Origin V...
#
#                                           raise_link  \
# 0  https://www.finsmes.com/2021/08/pumpspotting-r...
# 1  https://www.finsmes.com/2021/08/bldup-raises-2...
# 2  https://www.finsmes.com/2021/08/sicona-battery...
# 3  https://www.finsmes.com/2021/08/part-analytics...
# 4  https://www.finsmes.com/2021/08/anthill-raises...
#
#                  company_website company_funding_round company_category  \
# 0  https://www.pumpspotting.com/                  Seed          Femtech
# 1              http://bldup.com/              Pre-Seed       Enterprise
# 2  http://www.siconabattery.com/                     A           Energy
# 3     https://partanalytics.com/                     U       Industrial
# 4     https://www.anthillai.com/                  Seed       Enterprise
#
#                                  company_description company_expansion_plans  \
# 0    community-driven breastfeeding support platform                     NaN
# 1  system to highlight the relationship between b...                     NaN
# 2                       battery materials technology                     NaN
# 3  AI platform for sclaing global manufacturing c...                     NaN
# 4  talent management platform designed for remote...                     NaN
#
#   founder_first_name founder_last_name founder_linkedin founder_twitter  \
# 0                NaN               NaN              NaN             NaN
# 1                NaN               NaN              NaN             NaN
# 2                NaN               NaN              NaN             NaN
# 3                NaN               NaN              NaN             NaN
# 4                NaN               NaN              NaN             NaN
#
#   founder_angelist founder_email
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# founder_email                25632
# company_expansion_plans      24233
# founder_angelist             22976
# founder_twitter              22525
# founder_linkedin             16216
# founder_last_name            15169
# founder_first_name           15155
# company_website               4554
# company_description             47
# company_hq_location             44
# raise_top_investors              8
# company_category                 1
# company_name                     0
# company_funding_round            0
# raise_link                       0
# raise_amount_mill_dollars        0
# raise_date                       0
# dtype: int64

# %%
df['raise_amount_mill_dollars'] = pd.to_numeric(df['raise_amount_mill_dollars']).astype(np.int64)
df['raise_amount_mill_dollars'] = df['raise_amount_mill_dollars'].map(lambda x: x/1_000_000)

df['raise_date'] = pd.to_datetime(df['raise_date'], errors='coerce', format="%m/%d/%Y")
df['raise_date'] = df['raise_date'].bfill(axis=0) # back fill incorrect dates
df.dtypes
# Out:
# raise_date                   datetime64[ns]
# company_name                         object
# raise_amount_mill_dollars           float64
# company_hq_location                  object
# raise_top_investors                  object
# raise_link                           object
# company_website                      object
# company_funding_round                object
# company_category                     object
# company_description                  object
# company_expansion_plans              object
# founder_first_name                   object
# founder_last_name                    object
# founder_linkedin                     object
# founder_twitter                      object
# founder_angelist                     object
# founder_email                        object
# dtype: object

# %%
df['raise_date'].dt.strftime('%Y-%M-%d')
# Out:
# 0        2021-00-12
# 1        2021-00-12
# 2        2021-00-12
# 3        2021-00-12
# 4        2021-00-12
#             ...
# 25848    2016-00-07
# 25849    2016-00-09
# 25850    2016-00-08
# 25851    2016-00-09
# 25852    2016-00-10
# Name: raise_date, Length: 25853, dtype: object

# %%
df.head()
# Out:
#   raise_date    company_name  raise_amount_mill_dollars company_hq_location  \
# 0 2021-08-12    pumpspotting                       1.15        Kittery; Me.
# 1 2021-08-12           BLDUP                       2.00       Boston; Mass.
# 2 2021-08-12  Sicona Battery                       2.70   Sydney; Australia
# 3 2021-08-12  Part Analytics                       3.00    Milwaukee; Wisc.
# 4 2021-08-12         Anthill                       3.00       Chicago; Ill.
#
#                                  raise_top_investors  \
# 0  MooDoos Investments; participation from Maine ...
# 1                                                  U
# 2  Artesian; Riverstone Ventures; participation f...
# 3                                         MK Capital
# 4  Rethink Education; participation from Origin V...
#
#                                           raise_link  \
# 0  https://www.finsmes.com/2021/08/pumpspotting-r...
# 1  https://www.finsmes.com/2021/08/bldup-raises-2...
# 2  https://www.finsmes.com/2021/08/sicona-battery...
# 3  https://www.finsmes.com/2021/08/part-analytics...
# 4  https://www.finsmes.com/2021/08/anthill-raises...
#
#                  company_website company_funding_round company_category  \
# 0  https://www.pumpspotting.com/                  Seed          Femtech
# 1              http://bldup.com/              Pre-Seed       Enterprise
# 2  http://www.siconabattery.com/                     A           Energy
# 3     https://partanalytics.com/                     U       Industrial
# 4     https://www.anthillai.com/                  Seed       Enterprise
#
#                                  company_description company_expansion_plans  \
# 0    community-driven breastfeeding support platform                     NaN
# 1  system to highlight the relationship between b...                     NaN
# 2                       battery materials technology                     NaN
# 3  AI platform for sclaing global manufacturing c...                     NaN
# 4  talent management platform designed for remote...                     NaN
#
#   founder_first_name founder_last_name founder_linkedin founder_twitter  \
# 0                NaN               NaN              NaN             NaN
# 1                NaN               NaN              NaN             NaN
# 2                NaN               NaN              NaN             NaN
# 3                NaN               NaN              NaN             NaN
# 4                NaN               NaN              NaN             NaN
#
#   founder_angelist founder_email
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN

# %%
df[df['raise_date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [raise_date, company_name, raise_amount_mill_dollars, company_hq_location, raise_top_investors, raise_link, company_website, company_funding_round, company_category, company_description, company_expansion_plans, founder_first_name, founder_last_name, founder_linkedin, founder_twitter, founder_angelist, founder_email]
# Index: []

# %% [markdown]
# #### Checking data within columns

# %% [markdown]
# There are a number of incorrect manual entries in the category column - in the short term, these are replaced for more consistent groupings. However, in practice validation should be added to inputs for consistency.

# %%
df['company_category'].replace({
        'Agtech':'Agritech', 'Fermtech':'Femtech', 'COnsumer':'Consumer',
        'Foodtecvh':'Foodtech', 'INsurance':'Insurance','biotech/Health':'Biotech/Health',
        'insurtech':'Insurtech','ADtech/Martech':'Adtech/Martech','FIntech':'Fintech', 
        'enterprise':'Enterprise','Analyitcs':'Analytics', 'Consumert':'Consumer', 
        'Enteprrise':'Enterprise', 'Cosnumer':'Consumer', 'Energyteech':'Energytech',
        'industrial':'Industrial', 'INdustrial':'Industrial','Aerospacee':'Aerospace',
        'consumer':'Consumer', 'Ai/ML':'AI/ML', 'DevOPs':'DevOps', 
        'cannabis':'Cannabis', 'Data/Analtics':'Data/Analytics','Aadtech/Martech':'Adtech/Martech', 
        'ENterprise':'Enterprise', 'CLimatetech':'Climatetech', 'BIotech/Health':'Biotech/Health', 
        'Transportationn':'Trasportation', 'INsurtech':'Insuretech', 'Aeroospace':'Aerospace', 
        'Coonsumer':'Consumer', 'Logistcs':'Logistics','Fitnech':'Fintech', 
        'DEvOps':'Devops','Transportaiton':'Transportation', 'Transportatioon':'Transportation',
        'AI//ML':'AI/ML', 'Adtech/Marthech':'Adtech/Martech','Cybersercurity':'Cybersecurity', 
        'Insurtech ':'Insurtech','transportation':'Transportation', 'Consumer ':'Consumer',
        'Cyber-Security':'Cybersecurity', 'Ed-tech':'Edtech','Ed-Tech':'Edtech', 'Agech':'Agritech',
        'Cybsersecurity':'Cybersecurity','Roboticis':'Robotics','Finteech':'Fintech',
        'Eneterprise':'Enterprise', 'Cybesecurity':'Cybersecurity','Ai/mL':'AI/ML', 
        'Adtech/Marthec':'Adtech/Martech','BIOtech/Health':'Biotech/Health', 'data/Analytics':'Data/Analytics',
        'fintech':'Fintech', 'BLockchain':'Blockchain','Ccannabis':'Cannabis', 'robotics':'Robotics', 
        'Spacetechc':'Spacetech', 'Data/Analttics':'Data/Analytics','Consumer Internnet':'Consumer Internet', 
        'adtech/Martech':'Adtech/Martech', 'Biotech/Healthy':'Biotech/Health', 'COnsumer Internet':'Consumer Internet', 
        'Space':'Spacetech', 'DevOpds':'DevOps', 'Enterpris':'Enterprise','Consuner Internet':'Consumer Internet', 
        'Lifestyler':'Lifestyle','SpaceTech':'Spacetech','Govtech':'GovTech','Insuretech':'Insurtech',
        'Regtech':'RegTech', 'Enterprise Solution':'Enterprise Solutions','Martech':'Adtech/Martech', 
        'Transporatation':'Transportation','Biotech/Helath':'Biotech/Health', 'Devops':'DevOps',
        'Cybersecurity ':'Cybersecurity','Consumer INternet':'Consumer Internet', 'CYbersecurity':'Cybersecurity',
        'Ai/Machine Learning':'AI/ML', 'consumer Internet':'Consumer Internet', 'Enterprising':'Enterprise Solutions',
        'DAta/Analytics':'Data/Analytics', 'Enterprise solutions':'Enterprise Solutions','AI/Machine Learnign':'AI/ML',
        'bIOtech/Health':'Biotech/Health','bIotech/Health':'Biotech/Health', 'DEv':'Dev',
        'Quantum Computing ':'Quantum Computing','AI/Machine Leaning':'AI/ML', 'gaming':'Gaming',
        'Data/StorageAnalytics':'Data/Analytics', 'Consumer Interet':'Consumer Internet', 'Devops':'DevOps',
        'Cybersecuity':'Cybersecurity', 'AI/Machine Learing':'AI/ML', 'Data/Anlalytics':'Data/Analytics',
        'CLeantech':'Cleantech', 'Adtech':'Adtech/Martech', 'Footech':'Foodtech', 'COnsumer INternet':'Consumer Internet',
        'Bioetech/Health':'Biotech/Health', 'Data':'Data/Analytics', 'edtech':'Edtech', 'AR/Vr':'AR/VR', 
        'Enteprise':'Enterprise', 'Industry.40':'Industry4.0', 'Biotech/Heath':'Biotech/Health', 
        'Cyberecurity':'Cybersecurity', 'Food Tech':'Foodtech', 'Blochchain':'Blockchain', 'Gamng':'Gaming',
        'Customer Internet':'Consumer Internet', 'Entperprise':'Enterprise', 'PRoptech':'Proptech',
        'Real Esate':'Real estate', 'Trasportation':'Transportation', 'Edtec':'Edtech',
        'Ar/VR':'AR/VR', 'LIfestyle':'Lifestyle', 'lifestyle':'Lifestyle', 'Isurtech':'Insurtech',
        'Cleawntech':'Cleantech', 'Consumer Internt':'Consumer Internet', 'industral':'Industrial',
        'Industrials':'Industrial', 'Data/Analytis':'Data/Analytics', 'proptech':'Proptech',
        'Cybersecurit':'Cybersecurity', 'SPacetech':'Spacetech', 'REal Estate':'Real estate',
        'Insurteh':'Insurtech', 'INdustry4.0':'Industry4.0', 'RObotics':'Robotics',
        'Customer Products':'Consumer Products', 'Cybersecurirty':'Cybersecurity','cOnsumer Internet':'Consumer Internet',
        'Consumer Intenet':'Consumer Internet', 'Enterpise':'Enterprise', 'Biotech/Heatlh':'Biotech/Health',
        'Industral':'Industrial', 'dev':'Dev', 'Clean Tech':'CleanTech', 'Consumer Goods': 'Consumer Products',
        'Socialtecch':'Socialtech', 'blockchain':'Blockchain', 'AIML':'AI/ML', 'COnsumer Products':'Consumer Products',
        'FOodtech':'Foodtech', 'Gamers':'Gaming', 'Consumner Internet':'Consumer Internet',
        'Insrutech':'Insurtech', 'Insuretech':'Insurtech', 'Real estate':'Real Estate',
        'Real Estate Tech':'Proptech', 'Proptech':'PropTech','FinTech':'Fintech', 'Transporation':'Transportation',
        'TravelTech':'Traveltech','Telecom':'Telecoms', 'CleanTech':'Cleantech',
        'ClimateTech':'Climatetech','GreenTech':'Greentech', 'LegalTech':'Legaltech', 
        'SportTech':'SportsTech', 'Sportstech':'SportsTech','Sporttech':'SportsTech', 'DeepTech':'Deeptech',
        'Socialtech':'SocialTech','SalesTech':'Salestech', 'Biotech/Health ':'Biotech/Health',
        'Analytics':'Data/Analytics', 'Robots':'Robotics', 'Consumer products':'Consumer Products', 
        'Insuretech ':'Insurtech', 'Devops':'DevOps', 'Proptech':'PropTech'
}, inplace=True)

# %%
pd.options.display.max_rows = 1000
df['company_category'].value_counts()
# df['company_category'].unique()
# Out:
# Biotech/Health            4941
# Enterprise                4687
# Fintech                   2628
# Consumer Internet         1846
# Cybersecurity             1281
# Edtech                     643
# Industrial                 640
# Data/Analytics             634
# Consumer                   604
# Adtech/Martech             598
# Transportation             527
# Blockchain                 451
# Lifestyle                  426
# PropTech                   420
# DevOps                     398
# Foodtech                   375
# AI/Machine Learning        369
# Insurtech                  362
# Gaming                     330
# Agritech                   327
# AI/ML                      320
# Cleantech                  294
# Logistics                  276
# Dev                        252
# Robotics                   245
# AR/VR                      217
# Industry4.0                209
# Cannabis                   138
# Energy                     135
# SocialTech                 124
# Deeptech                   109
# Data/Storage               108
# Spacetech                   97
# Consumer Products           93
# Real Estate                 76
# Telecoms                    68
# Femtech                     56
# GovTech                     56
# Aerospace                   53
# Legaltech                   53
# Salestech                   51
# Greentech                   36
# Media                       35
# Mobility                    24
# SportsTech                  20
# Enterprise Solutions        18
# Healthcare                  17
# Education                   17
# Climatetech                 13
# Marketing                   12
# RegTech                     11
# Cloud                       11
# IoT                         10
# Mobile                       9
# Industry                     8
# Insurance                    7
# Traveltech                   7
# Energytech                   7
# Drones                       6
# Insuretech                   6
# Big Data                     5
# Hardware                     5
# Biotech                      5
# Creator                      5
# Devops                       3
# Quantum Computing            3
# Proptech                     3
# Hospitality                  2
# Defense                      2
# Real estate                  2
# Safetytech                   2
# Transformation               2
# Communication                2
# Defensetech                  1
# Analytics                    1
# Wearables                    1
# Drones/Robotics              1
# CleanTech                    1
# Trasportation                1
# Games                        1
# Fitness                      1
# Socialtech                   1
# EV                           1
# Entertainment                1
# Food                         1
# Communications               1
# Customer                     1
# Moonshot                     1
# Comptech                     1
# Construction                 1
# Hardtech                     1
# Chemtech                     1
# Digital Infrastructure       1
# Name: company_category, dtype: int64

# %%
# cat_table = df[['company_category','raise_amount_dollars']].groupby('company_category').count()/1_000_000


cat_table = df[['company_category','raise_amount_mill_dollars']].groupby('company_category').agg({'raise_amount_mill_dollars': ['mean','count']})
cat_table.head()
# Out:
#                     raise_amount_mill_dollars
#                                          mean count
# company_category
# AI/ML                               38.361781   320
# AI/Machine Learning                 32.649986   369
# AR/VR                               22.928659   217
# Adtech/Martech                      24.155587   598
# Aerospace                           49.018302    53

# %%
save_url = "data/funding_data_clean.csv"
df.to_csv(save_url)

# %%
df= df.head(9500) # Keep max 10K entries for free heroku tier
df
# Out:
#      raise_date          company_name  raise_amount_mill_dollars  \
# 0    2021-08-12          pumpspotting                       1.15
# 1    2021-08-12                 BLDUP                       2.00
# 2    2021-08-12        Sicona Battery                       2.70
# 3    2021-08-12        Part Analytics                       3.00
# 4    2021-08-12               Anthill                       3.00
# ...         ...                   ...                        ...
# 9495 2019-12-18  Pathios Therapeutics                       8.80
# 9496 2019-12-18       BillingPlatform                      10.00
# 9497 2019-12-18                Teraki                      11.00
# 9498 2019-12-18           BC Platform                      15.00
# 9499 2019-12-18     1366 Technologies                      18.00
#
#       company_hq_location                                raise_top_investors  \
# 0            Kittery; Me.  MooDoos Investments; participation from Maine ...
# 1           Boston; Mass.                                                  U
# 2       Sydney; Australia  Artesian; Riverstone Ventures; participation f...
# 3        Milwaukee; Wisc.                                         MK Capital
# 4           Chicago; Ill.  Rethink Education; participation from Origin V...
# ...                   ...                                                ...
# 9495           Oxford; UK                            Canaan; Brandon Capital
# 9496           Denver; CO                                   Columbia Capital
# 9497      Berlin; Germany  Horizons Ventures; participation from Auto Lab...
# 9498  Zurich; Switzerland  IQVIA; participation from Debiopharm Innovatio...
# 9499          Bedford; MA               Breakthrough Energy Ventures; et al.
#
#                                              raise_link  \
# 0     https://www.finsmes.com/2021/08/pumpspotting-r...
# 1     https://www.finsmes.com/2021/08/bldup-raises-2...
# 2     https://www.finsmes.com/2021/08/sicona-battery...
# 3     https://www.finsmes.com/2021/08/part-analytics...
# 4     https://www.finsmes.com/2021/08/anthill-raises...
# ...                                                 ...
# 9495  http://www.finsmes.com/2019/12/pathios-therape...
# 9496  http://www.finsmes.com/2019/12/billingplatform...
# 9497  http://www.finsmes.com/2019/12/teraki-secures-...
# 9498  http://www.finsmes.com/2019/12/bc-platforms-ra...
# 9499  https://1366tech.com/2019/12/17/1366-technolog...
#
#                     company_website company_funding_round company_category  \
# 0     https://www.pumpspotting.com/                  Seed          Femtech
# 1                 http://bldup.com/              Pre-Seed       Enterprise
# 2     http://www.siconabattery.com/                     A           Energy
# 3        https://partanalytics.com/                     U       Industrial
# 4        https://www.anthillai.com/                  Seed       Enterprise
# ...                             ...                   ...              ...
# 9495        http://www.pathios.com/                     A   Biotech/Health
# 9496   https://billingplatform.com/                     B          Fintech
# 9497            https://teraki.com/                     A       Industrial
# 9498    http://www.bcplatforms.com/                     U   Biotech/Health
# 9499                            NaN                     E       Enterprise
#
#                                     company_description  \
# 0       community-driven breastfeeding support platform
# 1     system to highlight the relationship between b...
# 2                          battery materials technology
# 3     AI platform for sclaing global manufacturing c...
# 4     talent management platform designed for remote...
# ...                                                 ...
# 9495       therapies for autoimmune diseases and cancer
# 9496            cloud monetization and billing software
# 9497                       industrial/auto IoT platform
# 9498              genomic data management and analytics
# 9499                        molten silicon solar wafers
#
#      company_expansion_plans founder_first_name founder_last_name  \
# 0                        NaN                NaN               NaN
# 1                        NaN                NaN               NaN
# 2                        NaN                NaN               NaN
# 3                        NaN                NaN               NaN
# 4                        NaN                NaN               NaN
# ...                      ...                ...               ...
# 9495                     NaN                NaN               NaN
# 9496                     NaN                NaN               NaN
# 9497                     NaN                NaN               NaN
# 9498                     NaN                NaN               NaN
# 9499                     NaN                NaN               NaN
#
#      founder_linkedin founder_twitter founder_angelist founder_email
# 0                 NaN             NaN              NaN           NaN
# 1                 NaN             NaN              NaN           NaN
# 2                 NaN             NaN              NaN           NaN
# 3                 NaN             NaN              NaN           NaN
# 4                 NaN             NaN              NaN           NaN
# ...               ...             ...              ...           ...
# 9495              NaN             NaN              NaN           NaN
# 9496              NaN             NaN              NaN           NaN
# 9497              NaN             NaN              NaN           NaN
# 9498              NaN             NaN              NaN           NaN
# 9499              NaN             NaN              NaN           NaN
#
# [9500 rows x 17 columns]

# %%
save_url = "data/funding_data_cleancut.csv"
df.to_csv(save_url)

# %%
df.dtypes
# Out:
# raise_date                   datetime64[ns]
# company_name                         object
# raise_amount_mill_dollars           float64
# company_hq_location                  object
# raise_top_investors                  object
# raise_link                           object
# company_website                      object
# company_funding_round                object
# company_category                     object
# company_description                  object
# company_expansion_plans              object
# founder_first_name                   object
# founder_last_name                    object
# founder_linkedin                     object
# founder_twitter                      object
# founder_angelist                     object
# founder_email                        object
# dtype: object
